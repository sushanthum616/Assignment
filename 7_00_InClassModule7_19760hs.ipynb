# %% [markdown]
# <a href="https://colab.research.google.com/github/sushanthum616/Assignment/blob/main/7_00_InClassModule7_19760hs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# package to extract data from various Internet sources into a DataFrame
# make sure you have it installed
#!pip install pandas_datareader
import pandas_datareader.data as pdr


# package for dates
import datetime as dt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
start_date = '2015-01-01'

# %%
end_date = dt.datetime.today().strftime('%Y-%m-%d')

# %% [markdown]
# ### Step 3. Use Pandas Datarader to read the daily time series using yfinance library for the Apple stock (ticker symbol AAPL) between 2015-01-01 and today, assign it to df_apple and print it.

# %%
#!pip install yfinance
import yfinance as yf

# %%
yf.pdr_override()

# %%
df_apple = pdr.get_data_yahoo('AAPL', start = start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_apple.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.466455  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.777189  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.779430  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.112869  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.039341  237458000

# %%
df_apple.shape
# Out:
# (2251, 6)

# %% [markdown]
# ### Step 4. Add a new column "stock" to the dataframe and add the ticker symbol

# %%
df_apple['stock'] = 'AAPL'

# %% [markdown]
# ### Step 5. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
df_tesla = pdr.get_data_yahoo('TSLA', start=start_date, end=end_date)
df_tesla['stock']='TSLA'
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_msft = pdr.get_data_yahoo('MSFT', start=start_date, end=end_date)
df_tesla['stock']='MSFT'
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_ibm = pdr.get_data_yahoo('IBM', start=start_date, end=end_date)
df_tesla['stock']='IBM'
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### Step 6. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %%
df_c = pd.concat([df_apple, df_tesla, df_ibm, df_msft], axis=0)

# %%
df_c.shape
# Out:
# (9004, 7)

# %% [markdown]
# ### Step 7. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %%
df_c.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.466455  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.777189  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.779430  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.112869  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.039341  237458000
#
#            stock
# Date
# 2015-01-02  AAPL
# 2015-01-05  AAPL
# 2015-01-06  AAPL
# 2015-01-07  AAPL
# 2015-01-08  AAPL

# %%
df_c.reset_index(inplace= True)

# %%
df_c.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.466455
# 1 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.777189
# 2 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.779430
# 3 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.112869
# 4 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.039341
#
#       Volume stock
# 0  212818400  AAPL
# 1  257142000  AAPL
# 2  263188400  AAPL
# 3  160423600  AAPL
# 4  237458000  AAPL

# %%
df_c.set_index(['Date', 'stock'], inplace=True)

# %%
df_c.head()
# Out:
#                        Open       High        Low      Close  Adj Close  \
# Date       stock
# 2015-01-02 AAPL   27.847500  27.860001  26.837500  27.332500  24.466455
# 2015-01-05 AAPL   27.072500  27.162500  26.352501  26.562500  23.777189
# 2015-01-06 AAPL   26.635000  26.857500  26.157499  26.565001  23.779430
# 2015-01-07 AAPL   26.799999  27.049999  26.674999  26.937500  24.112869
# 2015-01-08 AAPL   27.307501  28.037500  27.174999  27.972500  25.039341
#
#                      Volume
# Date       stock
# 2015-01-02 AAPL   212818400
# 2015-01-05 AAPL   257142000
# 2015-01-06 AAPL   263188400
# 2015-01-07 AAPL   160423600
# 2015-01-08 AAPL   237458000

# %% [markdown]
# Step 8. Create a dataFrame called vol, with the volume values.

# %%
vol = df_c[['Volume']]

# %%
vol.head(10)
# Out:
#                      Volume
# Date       stock
# 2015-01-02 AAPL   212818400
# 2015-01-05 AAPL   257142000
# 2015-01-06 AAPL   263188400
# 2015-01-07 AAPL   160423600
# 2015-01-08 AAPL   237458000
# 2015-01-09 AAPL   214798000
# 2015-01-12 AAPL   198603200
# 2015-01-13 AAPL   268367600
# 2015-01-14 AAPL   195826400
# 2015-01-15 AAPL   240056000

# %% [markdown]
# ### Step 9. Aggregate the data of volume to weekly.
